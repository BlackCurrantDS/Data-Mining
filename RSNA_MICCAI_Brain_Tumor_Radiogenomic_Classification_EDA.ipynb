# %% [markdown]
# <a href="https://colab.research.google.com/github/BlackCurrantDS/Data-Mining/blob/master/RSNA_MICCAI_Brain_Tumor_Radiogenomic_Classification_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mv /content/drive/MyDrive/Kaggle/kaggle.json ~/.kaggle/kaggle.json

# %%
#setting permission
# !chmod 600 /root/.kaggle/kaggle.json

# %%
#connecting to API
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
#imports
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import zipfile

# %%
#lets see all the files from the Optiver dataset
api.competition_list_files('rsna-miccai-brain-tumor-radiogenomic-classification')
# Out:
# [train/00025/T1wCE/Image-115.dcm,
#  train/00025/T1wCE/Image-113.dcm,
#  train/00025/T1wCE/Image-107.dcm,
#  train/00025/T1wCE/Image-106.dcm,
#  train/00025/T1wCE/Image-10.dcm,
#  train/00025/T1wCE/Image-116.dcm,
#  train/00025/T1wCE/Image-1.dcm,
#  train/00025/T1wCE/Image-103.dcm,
#  train/00025/T1wCE/Image-102.dcm,
#  train/00025/T1wCE/Image-100.dcm,
#  train/00025/T1wCE/Image-109.dcm,
#  train/00025/T1wCE/Image-114.dcm,
#  train/00025/T1wCE/Image-101.dcm,
#  train/00025/T1wCE/Image-112.dcm,
#  train/00025/T1wCE/Image-104.dcm,
#  train/00025/T1wCE/Image-105.dcm,
#  train/00025/T1wCE/Image-111.dcm,
#  train/00025/T1wCE/Image-108.dcm,
#  train/00025/T1wCE/Image-11.dcm,
#  train/00025/T1wCE/Image-110.dcm,
#  train/00025/T1w/Image-12.dcm,
#  train/00025/T1w/Image-26.dcm,
#  train/00025/T1w/Image-24.dcm,
#  train/00025/T1w/Image-18.dcm,
#  train/00025/T1w/Image-15.dcm,
#  train/00025/T1w/Image-1.dcm,
#  train/00025/T1w/Image-13.dcm,
#  train/00025/T1w/Image-22.dcm,
# ...

# %%
#download all
api.competition_download_files('rsna-miccai-brain-tumor-radiogenomic-classification')

# %%
#download train labeles
! kaggle competitions download rsna-miccai-brain-tumor-radiogenomic-classification -f train_labels.csv
# Out:
# ...
#   0% 0.00/4.59k [00:00<?, ?B/s]
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/cli.py", line 51, in main
#     out = args.func(**command_args)
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 735, in competition_download_cli
#     force, quiet)
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 677, in competition_download_file
#     self.download_file(response, outfile, quiet)
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 1512, in download_file
#     out.write(data)
# IOError: [Errno 28] No space left on device

# %%
#unzip
zf = zipfile.ZipFile('/content/rsna-miccai-brain-tumor-radiogenomic-classification.zip')
#extracted data is saved in the same directory as notebook
zf.extractall('/content/brain_tumor') 
zf.close()

# %%
#lets see training tables
train_ = pd.read_csv(dataset_path/'train_labels.csv')
print(f'There are {len(train_df)} patients in the dataset')
